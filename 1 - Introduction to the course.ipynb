# %% [markdown]
# # Introduction

# %% [markdown]
# ## Why text mining, now

# %% [markdown]
# ### New sources and scales of text data
#
# * Generated by students as they work online
# * From the internet
# * From books, etc.
#
# ### New computer-based techniques for working with and analyzing this data
#
# * More powerful computers
# * New algorithms
# * New tools

# %% [markdown]
# ## The lay of the land

# %% [markdown]
# ### Educational data mining
#
# * Came out of intelligent tutoring literature
#
# ### Learning analytics
#
# * Driven by emergence of data generated by student online work
# * Often an emphasis on data visualization and relatively simple metrics.
#
# ### Text mining as a subset
#
# * Can include mining of speech

# %% [markdown]
# ## Some sample types of use

# %% [markdown]
# ### Word co-occurrence patterns

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Measures of textual coherence and reading difficulty

# %% [markdown]
# ### Given a coded dataset, train a computer to code the same type of data.

# %% [markdown]
# <div>
# <img src="attachment:4409b814-0a47-4d69-bc8c-c39f5c0f7774.png" width="400"/>
# </div>

# %% [markdown]
# ### Automatically discover topics

# %% [markdown]
# ## My approach in this course

# %% [markdown]
# ### Extremely practical

# %% [markdown]
# ### What I want you to learn

# %% [markdown]
# * Enough to know what is possible
#     * This means understanding the space of algorithms
# * Enough practical skills that you know how to find resources, and build more extensive knowledge in the areas that you care about

# %% [markdown]
# ### A python-oriented toolset

# %% [markdown]
# * We'll be building python expertise a little at a time

# %% [markdown]
# # Course Outline

# %% [markdown]
# ## 1. Basics of Python and Text Analysis (~ 2 weeks)

# %% [markdown]
# * First steps with Python
# * Installing and getting started with the toolset
# * First steps with text analysis
#     * Simple explorations of word use
#     * Sentiment analysis
#     * Basic Tagging
#     * Counting Words
#     * Representations of co-occurrence
#     * Collocations and n-grams

# %% [markdown]
# ## 2. Text Classification (~ 2 weeks)

# %% [markdown]
# * Classification Methods
#     * Decision Trees
#     * Naive Bayes
#     * Support Vector Machines
#     * Neural Networks
# * Testing frameworks
# * Look at some tools with Graphical User Interfaces

# %% [markdown]
# ## 3. Negotiating the problems of real data (~1.5 weeks)
# * Assembling raw data
#     * From the web: web pages, twitter, etc.
#     * From PDFs
# * Cleaning
# * Normalizing
#     * Tokenizing
#     * Stemming
#     * Lemmatizing
#     * Regular Expressions

# %% [markdown]
# ## 3. Vector space methods (~1.5 weeks)

# %% [markdown]
# * About bag-of-words approaches
# * Converting text to a vector
# * Various representations of vectors
# * Use of vector representations to measure text similarity
# * Distributed vector representations (word embeddings)

# %% [markdown]
# ## 4. Unsupervised methods (~1.5 Weeks)

# %% [markdown]
# * Text Clustering
# * Topic Modeling

# %% [markdown]
# ## 5. Toward New Conceptualizations of Methods in LS (1 Week)

# %% [markdown]
# * A week of readings

# %% [markdown]
# ## Other Topics

# %% [markdown]
# * Networks

# %% [markdown]
# # Work that you'll do

# %% [markdown]
# 1. Weekly workbook-based analysis tasks
# 2. One tool report
# 3. Assemble one corpus of your own. Propose and complete an analysis.
# 4. A few readings
